# %%
import pandas as pd

# %%
products = pd.read_csv("products.csv")

# %%
products
# Out:
#     product_id                                       product_name  \
# 0            1                                 SUDAN GRASS POLLEN
# 1            2         Argentum Vesica urinaria 8/5 Special Order
# 2            3                           PHENDIMETRAZINE TARTRATE
# 3            4                              Rivastigmine Tartrate
# 4            5                             Motion Sickness Relief
# ..         ...                                                ...
# 95          96                        Pramipexole Dihydrochloride
# 96          97  ANTI-AGING CONCEALER FACE EYES SUNSCREEN SPF 2...
# 97          98                                   Allergy Medicine
# 98          99                                Night Time Original
# 99         100                                  Secura Protective
#
#                             brand_name  cost_price  selling_price  \
# 0           Allergy Laboratories, Inc.         227            140
# ...

# %%
products[0:10]
# Out:
#    product_id                                product_name  \
# 0           1                          SUDAN GRASS POLLEN
# 1           2  Argentum Vesica urinaria 8/5 Special Order
# 2           3                    PHENDIMETRAZINE TARTRATE
# 3           4                       Rivastigmine Tartrate
# 4           5                      Motion Sickness Relief
# 5           6         MDSolarSciences SPF40 No Touch Body
# 6           7                                 Bahia Grass
# 7           8                    Ropinirole Hydrochloride
# 8           9    Tramadol Hydrochloride and Acetaminophen
# 9          10      Waterless Anti-Bacterial Hand Cleanser
#
#                          brand_name  cost_price  selling_price  \
# 0        Allergy Laboratories, Inc.         227            140
# 1               Uriel Pharmacy Inc.         234            162
# 2                     Actavis, Inc.         262            182
# 3  Breckenridge Pharmaceutical, Inc          96            163
# ...

# %%
for i in range(10):
    f = open(f"products_{i+1}.csv", 'w')
    f.close()

# %%
columns = []

for i in products:
    columns.append(i)
print(columns)
# Out:
# ['product_id', 'product_name', 'brand_name', 'cost_price', 'selling_price', 'category', 'expiry_date']

# %%
first_slice = 0
second_slice = 10
file_counter = 1

while file_counter <= 10:
    
    writing_data = products[first_slice:second_slice]
    writing_data.to_csv(f'products_{file_counter}.csv', mode='a', index=True, header=columns)
    first_slice += 10
    second_slice += 10
    file_counter += 1

# %%
import random 

num = random.randint(1, 13)

# %%
num
# Out:
# 3

# %%
import pandas as pd

# %%
prodData = pd.read_csv("products_7.csv")

# %%
prodData
# Out:
#     product_id                                     product_name  \
# 60          61                       equaline triple antibiotic
# 61          62  CLARINS BB Skin Perfecting Cream SPF 25 Tint 00
# 62          63                   Dexamethasone sodium phosphate
# 63          64                                       Famotidine
# 64          65                                           CapCof
# 65          66                        Olanzapine and Fluoxetine
# 66          67                                       RANITIDINE
# 67          68                              Hydroxyzine Pamoate
# 68          69  JEUNCELL Hair restorer and Hair Growth Solution
# 69          70                                   Oral Analgesic
#
#                                            brand_name  cost_price  \
# 60                                      Supervalu Inc          48
# 61                          Laboratoires Clarins S.A.         128
# ...
